# %%
import numpy as np

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def sigmoid_derivative(x):
    return sigmoid(x) * (1 - sigmoid(x))

def step(x):
    return np.heaviside(x, 0.5)

# %%
# Set the parameters of the problem
a = 0.5
b = 0.6
r = 0.4

# %%
# Generate the training and testing data
np.random.seed(0)
train_data = np.random.rand(100, 2)
train_labels = np.array([1 if (x-a)**2 + (y-b)**2 < r**2 else 0 for x, y in train_data]).reshape(-1, 1)
test_data = np.random.rand(100, 2)
test_labels = np.array([1 if (x-a)**2 + (y-b)**2 < r**2 else 0 for x, y in test_data]).reshape(-1, 1)

# %%
# Initialize the weights randomly
np.random.seed(1)
W1 = np.random.randn(2, 10)
b1 = np.zeros((1, 10))
W2 = np.random.randn(10, 1)
b2 = np.zeros((1, 1))

# %%
# Set the learning rate and the number of epochs
learning_rate = 0.1
num_epochs = 1000

# %%
# Train the network using error back-propagation
for epoch in range(num_epochs):
    # Forward pass
    Z1 = np.dot(train_data, W1) + b1
    A1 = sigmoid(Z1)
    Z2 = np.dot(A1, W2) + b2
    Y_hat = sigmoid(Z2)
    
    # Compute the loss and the gradients
    error = train_labels - Y_hat
    dZ2 = error * sigmoid_derivative(Z2)
    dW2 = np.dot(A1.T, dZ2)
    db2 = np.sum(dZ2, axis=0, keepdims=True)
    dZ1 = np.dot(dZ2, W2.T) * sigmoid_derivative(Z1)
    dW1 = np.dot(train_data.T, dZ1)
    db1 = np.sum(dZ1, axis=0, keepdims=True)
    
    # Update the weights
    W2 += learning_rate * dW2
    b2 += learning_rate * db2
    W1 += learning_rate * dW1
    b1 += learning_rate * db1
    
    # Compute the accuracy on the training and testing data
    train_accuracy = np.mean(np.round(Y_hat) == train_labels)
    Z1_test = np.dot(test_data, W1) + b1
    A1_test = sigmoid(Z1_test)
    Z2_test = np.dot(A1_test, W2) + b2
    Y_hat_test = sigmoid(Z2_test)
    test_accuracy = np.mean(np.round(Y_hat_test) == test_labels)
    
    # Print the progress
    if (epoch+1) % 100 == 0:
        print(f"Epoch {epoch+1}/{num_epochs}: train accuracy={train_accuracy:.3f}, test accuracy={test_accuracy:.3f}")
# Out:
# Epoch 100/1000: train accuracy=0.720, test accuracy=0.660
# Epoch 200/1000: train accuracy=0.760, test accuracy=0.720
# Epoch 300/1000: train accuracy=0.820, test accuracy=0.830
# Epoch 400/1000: train accuracy=0.840, test accuracy=0.800
# Epoch 500/1000: train accuracy=0.850, test accuracy=0.830
# Epoch 600/1000: train accuracy=0.920, test accuracy=0.890
# Epoch 700/1000: train accuracy=0.950, test accuracy=0.960
# Epoch 800/1000: train accuracy=0.950, test accuracy=0.980
# Epoch 900/1000: train accuracy=0.960, test accuracy=0.980
# Epoch 1000/1000: train accuracy=0.970, test accuracy=0.980

# %%
# Compute the hyperplanes corresponding to the hidden nodes
H = sigmoid(np.dot(test_data, W1) + b1)
H_step = step

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Plot the hyperplanes
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(test_data[:, 0], test_data[:, 1], H[:, 0], c=test_labels[:, 0])
for i in range(10):
    xx, yy = np.meshgrid(np.linspace(0, 1, 10), np.linspace(0, 1, 10))
    zz = (-(W1[0, i]*xx + W1[1, i]*yy + b1[0, i]) / W1[2, i]).clip(0, 1)
    ax.plot_surface(xx, yy, zz, alpha=0.1)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12336\2926157293.py in <module>
#       8 for i in range(10):
#       9     xx, yy = np.meshgrid(np.linspace(0, 1, 10), np.linspace(0, 1, 10))
# ---> 10     zz = (-(W1[0, i]*xx + W1[1, i]*yy + b1[0, i]) / W1[2, i]).clip(0, 1)
#      11     ax.plot_surface(xx, yy, zz, alpha=0.1)
#      12 ax.set_xlabel('X')
#
# IndexError: index 2 is out of bounds for axis 0 with size 2

# %%
import numpy as np

# sigmoid function and its derivative
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def sigmoid_derivative(x):
    return sigmoid(x) * (1 - sigmoid(x))

# define the network architecture
input_size = 2
hidden_size = 10
output_size = 1

# initialize the weights with random values
weights1 = np.random.uniform(size=(input_size, hidden_size))
weights2 = np.random.uniform(size=(hidden_size, output_size))

# define the training parameters
learning_rate = 0.1
num_epochs = 1000
num_samples = 100

# generate training and testing data
a, b, r = 0.5, 0.6, 0.4
train_inputs = np.random.uniform(size=(num_samples, input_size))
train_outputs = np.zeros((num_samples, output_size))
for i in range(num_samples):
    x, y = train_inputs[i]
    if (x - a)**2 + (y - b)**2 < r**2:
        train_outputs[i] = 1

test_inputs = np.random.uniform(size=(num_samples, input_size))
test_outputs = np.zeros((num_samples, output_size))
for i in range(num_samples):
    x, y = test_inputs[i]
    if (x - a)**2 + (y - b)**2 < r**2:
        test_outputs[i] = 1

# train the network using error back-propagation
for epoch in range(num_epochs):
    # forward pass
    hidden_layer = sigmoid(np.dot(train_inputs, weights1))
    output_layer = sigmoid(np.dot(hidden_layer, weights2))

    # compute the error and the delta for the output layer
    error = train_outputs - output_layer
    output_delta = error * sigmoid_derivative(output_layer)

    # compute the delta for the hidden layer
    hidden_delta = output_delta.dot(weights2.T) * sigmoid_derivative(hidden_layer)

    # update the weights
    weights2 += learning_rate * hidden_layer.T.dot(output_delta)
    weights1 += learning_rate * train_inputs.T.dot(hidden_delta)

    # compute the accuracy on the training data
    train_accuracy = np.mean((output_layer > 0.5) == train_outputs)

    # compute the accuracy on the testing data
    hidden_layer_test = sigmoid(np.dot(test_inputs, weights1))
    output_layer_test = sigmoid(np.dot(hidden_layer_test, weights2))
    test_accuracy = np.mean((output_layer_test > 0.5) == test_outputs)

    print(f"Epoch {epoch}: train accuracy = {train_accuracy:.3f}, test accuracy = {test_accuracy:.3f}")

# compute the hyperplanes corresponding to the hidden nodes
for i in range(hidden_size):
    w = weights1[:, i]
    b = -w.dot(np.array([a, b]))
    print(f"Hyperplane {i}: w = {w}, b = {b}")
# Out:
# Epoch 0: train accuracy = 0.510, test accuracy = 0.460
# Epoch 1: train accuracy = 0.420, test accuracy = 0.470
# Epoch 2: train accuracy = 0.510, test accuracy = 0.420
# Epoch 3: train accuracy = 0.350, test accuracy = 0.470
# Epoch 4: train accuracy = 0.510, test accuracy = 0.380
# Epoch 5: train accuracy = 0.310, test accuracy = 0.470
# Epoch 6: train accuracy = 0.510, test accuracy = 0.520
# Epoch 7: train accuracy = 0.440, test accuracy = 0.470
# Epoch 8: train accuracy = 0.510, test accuracy = 0.530
# Epoch 9: train accuracy = 0.490, test accuracy = 0.470
# Epoch 10: train accuracy = 0.510, test accuracy = 0.530
# Epoch 11: train accuracy = 0.490, test accuracy = 0.470
# Epoch 12: train accuracy = 0.510, test accuracy = 0.530
# Epoch 13: train accuracy = 0.490, test accuracy = 0.470
# Epoch 14: train accuracy = 0.510, test accuracy = 0.530
# Epoch 15: train accuracy = 0.490, test accuracy = 0.470
# Epoch 16: train accuracy = 0.510, test accuracy = 0.530
# Epoch 17: train accuracy = 0.490, test accuracy = 0.470
# Epoch 18: train accuracy = 0.510, test accuracy = 0.530
# Epoch 19: train accuracy = 0.490, test accuracy = 0.470
# Epoch 20: train accuracy = 0.510, test accuracy = 0.530
# Epoch 21: train accuracy = 0.490, test accuracy = 0.470
# Epoch 22: train accuracy = 0.510, test accuracy = 0.530
# Epoch 23: train accuracy = 0.490, test accuracy = 0.470
# Epoch 24: train accuracy = 0.510, test accuracy = 0.530
# Epoch 25: train accuracy = 0.490, test accuracy = 0.470
# Epoch 26: train accuracy = 0.510, test accuracy = 0.530
# Epoch 27: train accuracy = 0.490, test accuracy = 0.470
# Epoch 28: train accuracy = 0.510, test accuracy = 0.530
# Epoch 29: train accuracy = 0.490, test accuracy = 0.470
# Epoch 30: train accuracy = 0.510, test accuracy = 0.530
# Epoch 31: train accuracy = 0.490, test accuracy = 0.470
# Epoch 32: train accuracy = 0.510, test accuracy = 0.530
# Epoch 33: train accuracy = 0.490, test accuracy = 0.470
# Epoch 34: train accuracy = 0.510, test accuracy = 0.530
# Epoch 35: train accuracy = 0.490, test accuracy = 0.470
# Epoch 36: train accuracy = 0.510, test accuracy = 0.530
# Epoch 37: train accuracy = 0.490, test accuracy = 0.470
# Epoch 38: train accuracy = 0.510, test accuracy = 0.530
# Epoch 39: train accuracy = 0.490, test accuracy = 0.470
# Epoch 40: train accuracy = 0.510, test accuracy = 0.530
# Epoch 41: train accuracy = 0.490, test accuracy = 0.470
# Epoch 42: train accuracy = 0.510, test accuracy = 0.530
# Epoch 43: train accuracy = 0.490, test accuracy = 0.470
# Epoch 44: train accuracy = 0.510, test accuracy = 0.530
# Epoch 45: train accuracy = 0.490, test accuracy = 0.470
# Epoch 46: train accuracy = 0.510, test accuracy = 0.530
# Epoch 47: train accuracy = 0.490, test accuracy = 0.470
# Epoch 48: train accuracy = 0.510, test accuracy = 0.530
# Epoch 49: train accuracy = 0.490, test accuracy = 0.470
# Epoch 50: train accuracy = 0.510, test accuracy = 0.530
# Epoch 51: train accuracy = 0.490, test accuracy = 0.470
# Epoch 52: train accuracy = 0.510, test accuracy = 0.530
# Epoch 53: train accuracy = 0.490, test accuracy = 0.470
# Epoch 54: train accuracy = 0.520, test accuracy = 0.530
# Epoch 55: train accuracy = 0.490, test accuracy = 0.490
# Epoch 56: train accuracy = 0.530, test accuracy = 0.510
# Epoch 57: train accuracy = 0.490, test accuracy = 0.530
# Epoch 58: train accuracy = 0.570, test accuracy = 0.470
# Epoch 59: train accuracy = 0.460, test accuracy = 0.580
# Epoch 60: train accuracy = 0.610, test accuracy = 0.460
# Epoch 61: train accuracy = 0.500, test accuracy = 0.640
# Epoch 62: train accuracy = 0.620, test accuracy = 0.500
# Epoch 63: train accuracy = 0.520, test accuracy = 0.660
# Epoch 64: train accuracy = 0.640, test accuracy = 0.500
# Epoch 65: train accuracy = 0.530, test accuracy = 0.670
# Epoch 66: train accuracy = 0.660, test accuracy = 0.520
# Epoch 67: train accuracy = 0.550, test accuracy = 0.720
# Epoch 68: train accuracy = 0.690, test accuracy = 0.570
# Epoch 69: train accuracy = 0.560, test accuracy = 0.730
# Epoch 70: train accuracy = 0.690, test accuracy = 0.610
# Epoch 71: train accuracy = 0.570, test accuracy = 0.750
# Epoch 72: train accuracy = 0.700, test accuracy = 0.590
# Epoch 73: train accuracy = 0.550, test accuracy = 0.770
# Epoch 74: train accuracy = 0.710, test accuracy = 0.600
# Epoch 75: train accuracy = 0.560, test accuracy = 0.750
# Epoch 76: train accuracy = 0.700, test accuracy = 0.610
# Epoch 77: train accuracy = 0.570, test accuracy = 0.740
# Epoch 78: train accuracy = 0.720, test accuracy = 0.610
# Epoch 79: train accuracy = 0.590, test accuracy = 0.760
# Epoch 80: train accuracy = 0.720, test accuracy = 0.600
# Epoch 81: train accuracy = 0.570, test accuracy = 0.760
# Epoch 82: train accuracy = 0.710, test accuracy = 0.600
# Epoch 83: train accuracy = 0.570, test accuracy = 0.750
# Epoch 84: train accuracy = 0.690, test accuracy = 0.620
# Epoch 85: train accuracy = 0.600, test accuracy = 0.740
# Epoch 86: train accuracy = 0.700, test accuracy = 0.610
# Epoch 87: train accuracy = 0.610, test accuracy = 0.750
# Epoch 88: train accuracy = 0.700, test accuracy = 0.630
# Epoch 89: train accuracy = 0.630, test accuracy = 0.750
# Epoch 90: train accuracy = 0.700, test accuracy = 0.650
# Epoch 91: train accuracy = 0.630, test accuracy = 0.740
# Epoch 92: train accuracy = 0.680, test accuracy = 0.650
# Epoch 93: train accuracy = 0.630, test accuracy = 0.740
# Epoch 94: train accuracy = 0.670, test accuracy = 0.650
# Epoch 95: train accuracy = 0.640, test accuracy = 0.730
# Epoch 96: train accuracy = 0.670, test accuracy = 0.660
# Epoch 97: train accuracy = 0.650, test accuracy = 0.710
# Epoch 98: train accuracy = 0.660, test accuracy = 0.660
# Epoch 99: train accuracy = 0.650, test accuracy = 0.710
# Epoch 100: train accuracy = 0.660, test accuracy = 0.660
# Epoch 101: train accuracy = 0.650, test accuracy = 0.700
# Epoch 102: train accuracy = 0.660, test accuracy = 0.660
# Epoch 103: train accuracy = 0.650, test accuracy = 0.700
# Epoch 104: train accuracy = 0.650, test accuracy = 0.660
# Epoch 105: train accuracy = 0.650, test accuracy = 0.700
# Epoch 106: train accuracy = 0.650, test accuracy = 0.660
# Epoch 107: train accuracy = 0.650, test accuracy = 0.700
# Epoch 108: train accuracy = 0.650, test accuracy = 0.660
# Epoch 109: train accuracy = 0.650, test accuracy = 0.680
# Epoch 110: train accuracy = 0.650, test accuracy = 0.660
# Epoch 111: train accuracy = 0.660, test accuracy = 0.680
# Epoch 112: train accuracy = 0.650, test accuracy = 0.660
# Epoch 113: train accuracy = 0.660, test accuracy = 0.680
# Epoch 114: train accuracy = 0.650, test accuracy = 0.660
# Epoch 115: train accuracy = 0.660, test accuracy = 0.680
# Epoch 116: train accuracy = 0.650, test accuracy = 0.660
# Epoch 117: train accuracy = 0.660, test accuracy = 0.680
# Epoch 118: train accuracy = 0.650, test accuracy = 0.660
# Epoch 119: train accuracy = 0.660, test accuracy = 0.680
# Epoch 120: train accuracy = 0.660, test accuracy = 0.660
# Epoch 121: train accuracy = 0.660, test accuracy = 0.670
# Epoch 122: train accuracy = 0.660, test accuracy = 0.660
# Epoch 123: train accuracy = 0.660, test accuracy = 0.670
# Epoch 124: train accuracy = 0.660, test accuracy = 0.660
# Epoch 125: train accuracy = 0.650, test accuracy = 0.670
# Epoch 126: train accuracy = 0.660, test accuracy = 0.660
# Epoch 127: train accuracy = 0.650, test accuracy = 0.660
# Epoch 128: train accuracy = 0.660, test accuracy = 0.660
# Epoch 129: train accuracy = 0.650, test accuracy = 0.660
# Epoch 130: train accuracy = 0.650, test accuracy = 0.660
# Epoch 131: train accuracy = 0.650, test accuracy = 0.660
# Epoch 132: train accuracy = 0.650, test accuracy = 0.660
# Epoch 133: train accuracy = 0.650, test accuracy = 0.660
# Epoch 134: train accuracy = 0.650, test accuracy = 0.660
# Epoch 135: train accuracy = 0.650, test accuracy = 0.660
# Epoch 136: train accuracy = 0.650, test accuracy = 0.660
# Epoch 137: train accuracy = 0.650, test accuracy = 0.660
# Epoch 138: train accuracy = 0.650, test accuracy = 0.660
# Epoch 139: train accuracy = 0.650, test accuracy = 0.660
# Epoch 140: train accuracy = 0.650, test accuracy = 0.660
# Epoch 141: train accuracy = 0.650, test accuracy = 0.660
# Epoch 142: train accuracy = 0.650, test accuracy = 0.660
# Epoch 143: train accuracy = 0.650, test accuracy = 0.670
# Epoch 144: train accuracy = 0.650, test accuracy = 0.660
# Epoch 145: train accuracy = 0.650, test accuracy = 0.670
# Epoch 146: train accuracy = 0.650, test accuracy = 0.670
# Epoch 147: train accuracy = 0.650, test accuracy = 0.680
# Epoch 148: train accuracy = 0.650, test accuracy = 0.680
# Epoch 149: train accuracy = 0.650, test accuracy = 0.680
# Epoch 150: train accuracy = 0.650, test accuracy = 0.680
# Epoch 151: train accuracy = 0.650, test accuracy = 0.680
# Epoch 152: train accuracy = 0.650, test accuracy = 0.680
# Epoch 153: train accuracy = 0.650, test accuracy = 0.680
# Epoch 154: train accuracy = 0.650, test accuracy = 0.680
# Epoch 155: train accuracy = 0.650, test accuracy = 0.680
# Epoch 156: train accuracy = 0.650, test accuracy = 0.680
# Epoch 157: train accuracy = 0.650, test accuracy = 0.680
# Epoch 158: train accuracy = 0.650, test accuracy = 0.680
# Epoch 159: train accuracy = 0.650, test accuracy = 0.680
# Epoch 160: train accuracy = 0.650, test accuracy = 0.680
# Epoch 161: train accuracy = 0.650, test accuracy = 0.680
# Epoch 162: train accuracy = 0.650, test accuracy = 0.680
# Epoch 163: train accuracy = 0.650, test accuracy = 0.680
# Epoch 164: train accuracy = 0.650, test accuracy = 0.680
# Epoch 165: train accuracy = 0.650, test accuracy = 0.680
# Epoch 166: train accuracy = 0.650, test accuracy = 0.680
# Epoch 167: train accuracy = 0.650, test accuracy = 0.680
# Epoch 168: train accuracy = 0.650, test accuracy = 0.680
# Epoch 169: train accuracy = 0.650, test accuracy = 0.680
# Epoch 170: train accuracy = 0.650, test accuracy = 0.680
# Epoch 171: train accuracy = 0.650, test accuracy = 0.680
# Epoch 172: train accuracy = 0.650, test accuracy = 0.680
# Epoch 173: train accuracy = 0.650, test accuracy = 0.680
# Epoch 174: train accuracy = 0.650, test accuracy = 0.680
# Epoch 175: train accuracy = 0.650, test accuracy = 0.680
# Epoch 176: train accuracy = 0.650, test accuracy = 0.680
# Epoch 177: train accuracy = 0.650, test accuracy = 0.680
# Epoch 178: train accuracy = 0.650, test accuracy = 0.680
# Epoch 179: train accuracy = 0.650, test accuracy = 0.680
# Epoch 180: train accuracy = 0.650, test accuracy = 0.680
# Epoch 181: train accuracy = 0.650, test accuracy = 0.680
# Epoch 182: train accuracy = 0.650, test accuracy = 0.680
# Epoch 183: train accuracy = 0.650, test accuracy = 0.680
# Epoch 184: train accuracy = 0.650, test accuracy = 0.680
# Epoch 185: train accuracy = 0.650, test accuracy = 0.680
# Epoch 186: train accuracy = 0.650, test accuracy = 0.680
# Epoch 187: train accuracy = 0.650, test accuracy = 0.680
# Epoch 188: train accuracy = 0.650, test accuracy = 0.680
# Epoch 189: train accuracy = 0.650, test accuracy = 0.680
# Epoch 190: train accuracy = 0.650, test accuracy = 0.680
# Epoch 191: train accuracy = 0.650, test accuracy = 0.680
# Epoch 192: train accuracy = 0.650, test accuracy = 0.680
# Epoch 193: train accuracy = 0.650, test accuracy = 0.680
# Epoch 194: train accuracy = 0.650, test accuracy = 0.680
# Epoch 195: train accuracy = 0.650, test accuracy = 0.680
# Epoch 196: train accuracy = 0.650, test accuracy = 0.680
# Epoch 197: train accuracy = 0.650, test accuracy = 0.680
# Epoch 198: train accuracy = 0.650, test accuracy = 0.680
# Epoch 199: train accuracy = 0.650, test accuracy = 0.680
# Epoch 200: train accuracy = 0.650, test accuracy = 0.680
# Epoch 201: train accuracy = 0.650, test accuracy = 0.680
# Epoch 202: train accuracy = 0.650, test accuracy = 0.680
# Epoch 203: train accuracy = 0.650, test accuracy = 0.680
# Epoch 204: train accuracy = 0.650, test accuracy = 0.680
# Epoch 205: train accuracy = 0.650, test accuracy = 0.680
# Epoch 206: train accuracy = 0.650, test accuracy = 0.680
# Epoch 207: train accuracy = 0.650, test accuracy = 0.680
# Epoch 208: train accuracy = 0.650, test accuracy = 0.680
# Epoch 209: train accuracy = 0.650, test accuracy = 0.680
# Epoch 210: train accuracy = 0.650, test accuracy = 0.680
# Epoch 211: train accuracy = 0.650, test accuracy = 0.680
# Epoch 212: train accuracy = 0.650, test accuracy = 0.680
# Epoch 213: train accuracy = 0.650, test accuracy = 0.680
# Epoch 214: train accuracy = 0.650, test accuracy = 0.680
# Epoch 215: train accuracy = 0.650, test accuracy = 0.680
# Epoch 216: train accuracy = 0.650, test accuracy = 0.680
# Epoch 217: train accuracy = 0.650, test accuracy = 0.680
# Epoch 218: train accuracy = 0.650, test accuracy = 0.680
# Epoch 219: train accuracy = 0.650, test accuracy = 0.680
# Epoch 220: train accuracy = 0.650, test accuracy = 0.680
# Epoch 221: train accuracy = 0.650, test accuracy = 0.680
# Epoch 222: train accuracy = 0.650, test accuracy = 0.680
# Epoch 223: train accuracy = 0.650, test accuracy = 0.680
# Epoch 224: train accuracy = 0.650, test accuracy = 0.680
# Epoch 225: train accuracy = 0.650, test accuracy = 0.680
# Epoch 226: train accuracy = 0.650, test accuracy = 0.680
# Epoch 227: train accuracy = 0.650, test accuracy = 0.680
# Epoch 228: train accuracy = 0.650, test accuracy = 0.680
# Epoch 229: train accuracy = 0.650, test accuracy = 0.680
# Epoch 230: train accuracy = 0.650, test accuracy = 0.680
# Epoch 231: train accuracy = 0.650, test accuracy = 0.680
# Epoch 232: train accuracy = 0.650, test accuracy = 0.690
# Epoch 233: train accuracy = 0.650, test accuracy = 0.690
# Epoch 234: train accuracy = 0.650, test accuracy = 0.690
# Epoch 235: train accuracy = 0.650, test accuracy = 0.690
# Epoch 236: train accuracy = 0.650, test accuracy = 0.690
# Epoch 237: train accuracy = 0.650, test accuracy = 0.690
# Epoch 238: train accuracy = 0.650, test accuracy = 0.690
# Epoch 239: train accuracy = 0.650, test accuracy = 0.690
# Epoch 240: train accuracy = 0.650, test accuracy = 0.690
# Epoch 241: train accuracy = 0.650, test accuracy = 0.690
# Epoch 242: train accuracy = 0.650, test accuracy = 0.690
# Epoch 243: train accuracy = 0.650, test accuracy = 0.690
# Epoch 244: train accuracy = 0.650, test accuracy = 0.690
# Epoch 245: train accuracy = 0.650, test accuracy = 0.690
# Epoch 246: train accuracy = 0.650, test accuracy = 0.690
# Epoch 247: train accuracy = 0.650, test accuracy = 0.690
# Epoch 248: train accuracy = 0.650, test accuracy = 0.690
# Epoch 249: train accuracy = 0.650, test accuracy = 0.690
# Epoch 250: train accuracy = 0.650, test accuracy = 0.690
# Epoch 251: train accuracy = 0.650, test accuracy = 0.690
# Epoch 252: train accuracy = 0.650, test accuracy = 0.690
# Epoch 253: train accuracy = 0.650, test accuracy = 0.690
# Epoch 254: train accuracy = 0.650, test accuracy = 0.690
# Epoch 255: train accuracy = 0.650, test accuracy = 0.690
# Epoch 256: train accuracy = 0.650, test accuracy = 0.690
# Epoch 257: train accuracy = 0.650, test accuracy = 0.690
# Epoch 258: train accuracy = 0.650, test accuracy = 0.690
# Epoch 259: train accuracy = 0.650, test accuracy = 0.690
# Epoch 260: train accuracy = 0.650, test accuracy = 0.690
# Epoch 261: train accuracy = 0.650, test accuracy = 0.690
# Epoch 262: train accuracy = 0.650, test accuracy = 0.690
# Epoch 263: train accuracy = 0.650, test accuracy = 0.690
# Epoch 264: train accuracy = 0.650, test accuracy = 0.690
# Epoch 265: train accuracy = 0.650, test accuracy = 0.690
# Epoch 266: train accuracy = 0.650, test accuracy = 0.690
# Epoch 267: train accuracy = 0.650, test accuracy = 0.690
# Epoch 268: train accuracy = 0.650, test accuracy = 0.690
# Epoch 269: train accuracy = 0.650, test accuracy = 0.690
# Epoch 270: train accuracy = 0.650, test accuracy = 0.690
# Epoch 271: train accuracy = 0.650, test accuracy = 0.690
# Epoch 272: train accuracy = 0.650, test accuracy = 0.690
# Epoch 273: train accuracy = 0.650, test accuracy = 0.690
# Epoch 274: train accuracy = 0.650, test accuracy = 0.690
# Epoch 275: train accuracy = 0.650, test accuracy = 0.690
# Epoch 276: train accuracy = 0.650, test accuracy = 0.690
# Epoch 277: train accuracy = 0.650, test accuracy = 0.690
# Epoch 278: train accuracy = 0.650, test accuracy = 0.690
# Epoch 279: train accuracy = 0.650, test accuracy = 0.690
# Epoch 280: train accuracy = 0.650, test accuracy = 0.690
# Epoch 281: train accuracy = 0.650, test accuracy = 0.690
# Epoch 282: train accuracy = 0.650, test accuracy = 0.690
# Epoch 283: train accuracy = 0.650, test accuracy = 0.690
# Epoch 284: train accuracy = 0.650, test accuracy = 0.690
# Epoch 285: train accuracy = 0.650, test accuracy = 0.690
# Epoch 286: train accuracy = 0.650, test accuracy = 0.690
# Epoch 287: train accuracy = 0.650, test accuracy = 0.690
# Epoch 288: train accuracy = 0.650, test accuracy = 0.690
# Epoch 289: train accuracy = 0.650, test accuracy = 0.690
# Epoch 290: train accuracy = 0.650, test accuracy = 0.690
# Epoch 291: train accuracy = 0.650, test accuracy = 0.690
# Epoch 292: train accuracy = 0.650, test accuracy = 0.690
# Epoch 293: train accuracy = 0.650, test accuracy = 0.690
# Epoch 294: train accuracy = 0.650, test accuracy = 0.690
# Epoch 295: train accuracy = 0.650, test accuracy = 0.690
# Epoch 296: train accuracy = 0.650, test accuracy = 0.690
# Epoch 297: train accuracy = 0.650, test accuracy = 0.690
# Epoch 298: train accuracy = 0.650, test accuracy = 0.690
# Epoch 299: train accuracy = 0.650, test accuracy = 0.690
# Epoch 300: train accuracy = 0.650, test accuracy = 0.690
# Epoch 301: train accuracy = 0.650, test accuracy = 0.690
# Epoch 302: train accuracy = 0.650, test accuracy = 0.690
# Epoch 303: train accuracy = 0.650, test accuracy = 0.690
# Epoch 304: train accuracy = 0.650, test accuracy = 0.690
# Epoch 305: train accuracy = 0.650, test accuracy = 0.690
# Epoch 306: train accuracy = 0.650, test accuracy = 0.690
# Epoch 307: train accuracy = 0.650, test accuracy = 0.690
# Epoch 308: train accuracy = 0.650, test accuracy = 0.690
# Epoch 309: train accuracy = 0.650, test accuracy = 0.690
# Epoch 310: train accuracy = 0.650, test accuracy = 0.690
# Epoch 311: train accuracy = 0.650, test accuracy = 0.690
# Epoch 312: train accuracy = 0.650, test accuracy = 0.690
# Epoch 313: train accuracy = 0.650, test accuracy = 0.690
# Epoch 314: train accuracy = 0.650, test accuracy = 0.690
# Epoch 315: train accuracy = 0.650, test accuracy = 0.690
# Epoch 316: train accuracy = 0.650, test accuracy = 0.690
# Epoch 317: train accuracy = 0.650, test accuracy = 0.690
# Epoch 318: train accuracy = 0.650, test accuracy = 0.690
# Epoch 319: train accuracy = 0.650, test accuracy = 0.690
# Epoch 320: train accuracy = 0.650, test accuracy = 0.690
# Epoch 321: train accuracy = 0.650, test accuracy = 0.690
# Epoch 322: train accuracy = 0.650, test accuracy = 0.690
# Epoch 323: train accuracy = 0.650, test accuracy = 0.690
# Epoch 324: train accuracy = 0.650, test accuracy = 0.690
# Epoch 325: train accuracy = 0.650, test accuracy = 0.690
# Epoch 326: train accuracy = 0.650, test accuracy = 0.690
# Epoch 327: train accuracy = 0.650, test accuracy = 0.690
# Epoch 328: train accuracy = 0.650, test accuracy = 0.690
# Epoch 329: train accuracy = 0.650, test accuracy = 0.690
# Epoch 330: train accuracy = 0.650, test accuracy = 0.690
# Epoch 331: train accuracy = 0.650, test accuracy = 0.690
# Epoch 332: train accuracy = 0.650, test accuracy = 0.690
# Epoch 333: train accuracy = 0.650, test accuracy = 0.690
# Epoch 334: train accuracy = 0.650, test accuracy = 0.690
# Epoch 335: train accuracy = 0.650, test accuracy = 0.690
# Epoch 336: train accuracy = 0.650, test accuracy = 0.690
# Epoch 337: train accuracy = 0.650, test accuracy = 0.690
# Epoch 338: train accuracy = 0.650, test accuracy = 0.690
# Epoch 339: train accuracy = 0.650, test accuracy = 0.690
# Epoch 340: train accuracy = 0.650, test accuracy = 0.690
# Epoch 341: train accuracy = 0.650, test accuracy = 0.690
# Epoch 342: train accuracy = 0.650, test accuracy = 0.690
# Epoch 343: train accuracy = 0.650, test accuracy = 0.690
# Epoch 344: train accuracy = 0.650, test accuracy = 0.690
# Epoch 345: train accuracy = 0.650, test accuracy = 0.690
# Epoch 346: train accuracy = 0.650, test accuracy = 0.690
# Epoch 347: train accuracy = 0.650, test accuracy = 0.690
# Epoch 348: train accuracy = 0.650, test accuracy = 0.690
# Epoch 349: train accuracy = 0.650, test accuracy = 0.690
# Epoch 350: train accuracy = 0.650, test accuracy = 0.690
# Epoch 351: train accuracy = 0.650, test accuracy = 0.690
# Epoch 352: train accuracy = 0.650, test accuracy = 0.690
# Epoch 353: train accuracy = 0.650, test accuracy = 0.690
# Epoch 354: train accuracy = 0.650, test accuracy = 0.690
# Epoch 355: train accuracy = 0.650, test accuracy = 0.690
# Epoch 356: train accuracy = 0.650, test accuracy = 0.690
# Epoch 357: train accuracy = 0.650, test accuracy = 0.690
# Epoch 358: train accuracy = 0.650, test accuracy = 0.690
# Epoch 359: train accuracy = 0.650, test accuracy = 0.690
# Epoch 360: train accuracy = 0.650, test accuracy = 0.690
# Epoch 361: train accuracy = 0.650, test accuracy = 0.690
# Epoch 362: train accuracy = 0.650, test accuracy = 0.690
# Epoch 363: train accuracy = 0.650, test accuracy = 0.690
# Epoch 364: train accuracy = 0.650, test accuracy = 0.690
# Epoch 365: train accuracy = 0.650, test accuracy = 0.690
# Epoch 366: train accuracy = 0.650, test accuracy = 0.690
# Epoch 367: train accuracy = 0.650, test accuracy = 0.690
# Epoch 368: train accuracy = 0.650, test accuracy = 0.690
# Epoch 369: train accuracy = 0.650, test accuracy = 0.690
# Epoch 370: train accuracy = 0.650, test accuracy = 0.690
# Epoch 371: train accuracy = 0.650, test accuracy = 0.690
# Epoch 372: train accuracy = 0.650, test accuracy = 0.690
# Epoch 373: train accuracy = 0.650, test accuracy = 0.690
# Epoch 374: train accuracy = 0.650, test accuracy = 0.690
# Epoch 375: train accuracy = 0.650, test accuracy = 0.690
# Epoch 376: train accuracy = 0.650, test accuracy = 0.690
# Epoch 377: train accuracy = 0.650, test accuracy = 0.690
# Epoch 378: train accuracy = 0.650, test accuracy = 0.690
# Epoch 379: train accuracy = 0.650, test accuracy = 0.690
# Epoch 380: train accuracy = 0.650, test accuracy = 0.690
# Epoch 381: train accuracy = 0.650, test accuracy = 0.690
# Epoch 382: train accuracy = 0.650, test accuracy = 0.690
# Epoch 383: train accuracy = 0.650, test accuracy = 0.690
# Epoch 384: train accuracy = 0.650, test accuracy = 0.690
# Epoch 385: train accuracy = 0.650, test accuracy = 0.690
# Epoch 386: train accuracy = 0.650, test accuracy = 0.690
# Epoch 387: train accuracy = 0.650, test accuracy = 0.690
# Epoch 388: train accuracy = 0.650, test accuracy = 0.690
# Epoch 389: train accuracy = 0.650, test accuracy = 0.690
# Epoch 390: train accuracy = 0.650, test accuracy = 0.690
# Epoch 391: train accuracy = 0.650, test accuracy = 0.690
# Epoch 392: train accuracy = 0.650, test accuracy = 0.690
# Epoch 393: train accuracy = 0.650, test accuracy = 0.690
# Epoch 394: train accuracy = 0.650, test accuracy = 0.690
# Epoch 395: train accuracy = 0.650, test accuracy = 0.690
# Epoch 396: train accuracy = 0.650, test accuracy = 0.690
# Epoch 397: train accuracy = 0.650, test accuracy = 0.690
# Epoch 398: train accuracy = 0.650, test accuracy = 0.690
# Epoch 399: train accuracy = 0.650, test accuracy = 0.690
# Epoch 400: train accuracy = 0.650, test accuracy = 0.690
# Epoch 401: train accuracy = 0.650, test accuracy = 0.690
# Epoch 402: train accuracy = 0.650, test accuracy = 0.690
# Epoch 403: train accuracy = 0.650, test accuracy = 0.690
# Epoch 404: train accuracy = 0.650, test accuracy = 0.690
# Epoch 405: train accuracy = 0.650, test accuracy = 0.690
# Epoch 406: train accuracy = 0.650, test accuracy = 0.690
# Epoch 407: train accuracy = 0.650, test accuracy = 0.690
# Epoch 408: train accuracy = 0.650, test accuracy = 0.690
# Epoch 409: train accuracy = 0.650, test accuracy = 0.690
# Epoch 410: train accuracy = 0.650, test accuracy = 0.690
# Epoch 411: train accuracy = 0.650, test accuracy = 0.690
# Epoch 412: train accuracy = 0.650, test accuracy = 0.690
# Epoch 413: train accuracy = 0.650, test accuracy = 0.690
# Epoch 414: train accuracy = 0.650, test accuracy = 0.690
# Epoch 415: train accuracy = 0.650, test accuracy = 0.690
# Epoch 416: train accuracy = 0.650, test accuracy = 0.690
# Epoch 417: train accuracy = 0.650, test accuracy = 0.690
# Epoch 418: train accuracy = 0.650, test accuracy = 0.690
# Epoch 419: train accuracy = 0.650, test accuracy = 0.690
# Epoch 420: train accuracy = 0.650, test accuracy = 0.690
# Epoch 421: train accuracy = 0.650, test accuracy = 0.690
# Epoch 422: train accuracy = 0.650, test accuracy = 0.690
# Epoch 423: train accuracy = 0.650, test accuracy = 0.690
# Epoch 424: train accuracy = 0.650, test accuracy = 0.690
# Epoch 425: train accuracy = 0.650, test accuracy = 0.690
# Epoch 426: train accuracy = 0.650, test accuracy = 0.690
# Epoch 427: train accuracy = 0.650, test accuracy = 0.690
# Epoch 428: train accuracy = 0.650, test accuracy = 0.690
# Epoch 429: train accuracy = 0.650, test accuracy = 0.690
# Epoch 430: train accuracy = 0.650, test accuracy = 0.690
# Epoch 431: train accuracy = 0.650, test accuracy = 0.690
# Epoch 432: train accuracy = 0.650, test accuracy = 0.690
# Epoch 433: train accuracy = 0.650, test accuracy = 0.690
# Epoch 434: train accuracy = 0.650, test accuracy = 0.690
# Epoch 435: train accuracy = 0.650, test accuracy = 0.690
# Epoch 436: train accuracy = 0.650, test accuracy = 0.690
# Epoch 437: train accuracy = 0.650, test accuracy = 0.690
# Epoch 438: train accuracy = 0.650, test accuracy = 0.690
# Epoch 439: train accuracy = 0.650, test accuracy = 0.690
# Epoch 440: train accuracy = 0.650, test accuracy = 0.690
# Epoch 441: train accuracy = 0.650, test accuracy = 0.690
# Epoch 442: train accuracy = 0.650, test accuracy = 0.690
# Epoch 443: train accuracy = 0.650, test accuracy = 0.690
# Epoch 444: train accuracy = 0.650, test accuracy = 0.690
# Epoch 445: train accuracy = 0.650, test accuracy = 0.690
# Epoch 446: train accuracy = 0.650, test accuracy = 0.690
# Epoch 447: train accuracy = 0.650, test accuracy = 0.690
# Epoch 448: train accuracy = 0.650, test accuracy = 0.690
# Epoch 449: train accuracy = 0.650, test accuracy = 0.690
# Epoch 450: train accuracy = 0.650, test accuracy = 0.690
# Epoch 451: train accuracy = 0.650, test accuracy = 0.690
# Epoch 452: train accuracy = 0.650, test accuracy = 0.690
# Epoch 453: train accuracy = 0.650, test accuracy = 0.690
# Epoch 454: train accuracy = 0.650, test accuracy = 0.690
# Epoch 455: train accuracy = 0.650, test accuracy = 0.690
# Epoch 456: train accuracy = 0.650, test accuracy = 0.690
# Epoch 457: train accuracy = 0.650, test accuracy = 0.690
# Epoch 458: train accuracy = 0.650, test accuracy = 0.690
# Epoch 459: train accuracy = 0.650, test accuracy = 0.690
# Epoch 460: train accuracy = 0.650, test accuracy = 0.690
# Epoch 461: train accuracy = 0.650, test accuracy = 0.690
# Epoch 462: train accuracy = 0.650, test accuracy = 0.690
# Epoch 463: train accuracy = 0.650, test accuracy = 0.690
# Epoch 464: train accuracy = 0.650, test accuracy = 0.690
# Epoch 465: train accuracy = 0.650, test accuracy = 0.690
# Epoch 466: train accuracy = 0.650, test accuracy = 0.690
# Epoch 467: train accuracy = 0.650, test accuracy = 0.690
# Epoch 468: train accuracy = 0.650, test accuracy = 0.690
# Epoch 469: train accuracy = 0.650, test accuracy = 0.680
# Epoch 470: train accuracy = 0.650, test accuracy = 0.690
# Epoch 471: train accuracy = 0.650, test accuracy = 0.680
# Epoch 472: train accuracy = 0.650, test accuracy = 0.690
# Epoch 473: train accuracy = 0.650, test accuracy = 0.680
# Epoch 474: train accuracy = 0.650, test accuracy = 0.680
# Epoch 475: train accuracy = 0.650, test accuracy = 0.680
# Epoch 476: train accuracy = 0.660, test accuracy = 0.660
# Epoch 477: train accuracy = 0.650, test accuracy = 0.690
# Epoch 478: train accuracy = 0.670, test accuracy = 0.660
# Epoch 479: train accuracy = 0.650, test accuracy = 0.710
# Epoch 480: train accuracy = 0.670, test accuracy = 0.630
# Epoch 481: train accuracy = 0.630, test accuracy = 0.720
# Epoch 482: train accuracy = 0.680, test accuracy = 0.630
# Epoch 483: train accuracy = 0.630, test accuracy = 0.720
# Epoch 484: train accuracy = 0.680, test accuracy = 0.620
# Epoch 485: train accuracy = 0.600, test accuracy = 0.750
# Epoch 486: train accuracy = 0.690, test accuracy = 0.610
# Epoch 487: train accuracy = 0.570, test accuracy = 0.740
# Epoch 488: train accuracy = 0.710, test accuracy = 0.580
# Epoch 489: train accuracy = 0.550, test accuracy = 0.760
# Epoch 490: train accuracy = 0.710, test accuracy = 0.500
# Epoch 491: train accuracy = 0.540, test accuracy = 0.730
# Epoch 492: train accuracy = 0.700, test accuracy = 0.470
# Epoch 493: train accuracy = 0.500, test accuracy = 0.710
# Epoch 494: train accuracy = 0.660, test accuracy = 0.500
# Epoch 495: train accuracy = 0.470, test accuracy = 0.650
# Epoch 496: train accuracy = 0.660, test accuracy = 0.480
# Epoch 497: train accuracy = 0.470, test accuracy = 0.650
# Epoch 498: train accuracy = 0.660, test accuracy = 0.470
# Epoch 499: train accuracy = 0.490, test accuracy = 0.710
# Epoch 500: train accuracy = 0.660, test accuracy = 0.460
# Epoch 501: train accuracy = 0.500, test accuracy = 0.710
# Epoch 502: train accuracy = 0.670, test accuracy = 0.450
# Epoch 503: train accuracy = 0.490, test accuracy = 0.730
# Epoch 504: train accuracy = 0.690, test accuracy = 0.460
# Epoch 505: train accuracy = 0.530, test accuracy = 0.730
# Epoch 506: train accuracy = 0.700, test accuracy = 0.470
# Epoch 507: train accuracy = 0.520, test accuracy = 0.740
# Epoch 508: train accuracy = 0.710, test accuracy = 0.500
# Epoch 509: train accuracy = 0.540, test accuracy = 0.750
# Epoch 510: train accuracy = 0.720, test accuracy = 0.510
# Epoch 511: train accuracy = 0.540, test accuracy = 0.750
# Epoch 512: train accuracy = 0.710, test accuracy = 0.550
# Epoch 513: train accuracy = 0.540, test accuracy = 0.760
# Epoch 514: train accuracy = 0.710, test accuracy = 0.570
# Epoch 515: train accuracy = 0.570, test accuracy = 0.750
# Epoch 516: train accuracy = 0.700, test accuracy = 0.560
# Epoch 517: train accuracy = 0.570, test accuracy = 0.750
# Epoch 518: train accuracy = 0.710, test accuracy = 0.560
# Epoch 519: train accuracy = 0.550, test accuracy = 0.740
# Epoch 520: train accuracy = 0.700, test accuracy = 0.580
# Epoch 521: train accuracy = 0.540, test accuracy = 0.750
# Epoch 522: train accuracy = 0.700, test accuracy = 0.580
# Epoch 523: train accuracy = 0.550, test accuracy = 0.750
# Epoch 524: train accuracy = 0.700, test accuracy = 0.590
# Epoch 525: train accuracy = 0.550, test accuracy = 0.750
# Epoch 526: train accuracy = 0.710, test accuracy = 0.590
# Epoch 527: train accuracy = 0.550, test accuracy = 0.750
# Epoch 528: train accuracy = 0.710, test accuracy = 0.590
# Epoch 529: train accuracy = 0.550, test accuracy = 0.740
# Epoch 530: train accuracy = 0.710, test accuracy = 0.590
# Epoch 531: train accuracy = 0.560, test accuracy = 0.740
# Epoch 532: train accuracy = 0.720, test accuracy = 0.590
# Epoch 533: train accuracy = 0.570, test accuracy = 0.740
# Epoch 534: train accuracy = 0.710, test accuracy = 0.590
# Epoch 535: train accuracy = 0.570, test accuracy = 0.750
# Epoch 536: train accuracy = 0.710, test accuracy = 0.590
# Epoch 537: train accuracy = 0.570, test accuracy = 0.750
# Epoch 538: train accuracy = 0.710, test accuracy = 0.590
# Epoch 539: train accuracy = 0.560, test accuracy = 0.740
# Epoch 540: train accuracy = 0.710, test accuracy = 0.590
# Epoch 541: train accuracy = 0.560, test accuracy = 0.740
# Epoch 542: train accuracy = 0.710, test accuracy = 0.590
# Epoch 543: train accuracy = 0.560, test accuracy = 0.740
# Epoch 544: train accuracy = 0.710, test accuracy = 0.600
# Epoch 545: train accuracy = 0.550, test accuracy = 0.740
# Epoch 546: train accuracy = 0.710, test accuracy = 0.600
# Epoch 547: train accuracy = 0.550, test accuracy = 0.740
# Epoch 548: train accuracy = 0.710, test accuracy = 0.610
# Epoch 549: train accuracy = 0.550, test accuracy = 0.740
# Epoch 550: train accuracy = 0.710, test accuracy = 0.610
# Epoch 551: train accuracy = 0.560, test accuracy = 0.740
# Epoch 552: train accuracy = 0.710, test accuracy = 0.610
# Epoch 553: train accuracy = 0.560, test accuracy = 0.740
# Epoch 554: train accuracy = 0.710, test accuracy = 0.610
# Epoch 555: train accuracy = 0.560, test accuracy = 0.740
# Epoch 556: train accuracy = 0.710, test accuracy = 0.610
# Epoch 557: train accuracy = 0.560, test accuracy = 0.740
# Epoch 558: train accuracy = 0.710, test accuracy = 0.620
# Epoch 559: train accuracy = 0.560, test accuracy = 0.740
# Epoch 560: train accuracy = 0.710, test accuracy = 0.620
# Epoch 561: train accuracy = 0.560, test accuracy = 0.740
# Epoch 562: train accuracy = 0.710, test accuracy = 0.620
# Epoch 563: train accuracy = 0.560, test accuracy = 0.740
# Epoch 564: train accuracy = 0.710, test accuracy = 0.620
# Epoch 565: train accuracy = 0.560, test accuracy = 0.740
# Epoch 566: train accuracy = 0.710, test accuracy = 0.620
# Epoch 567: train accuracy = 0.560, test accuracy = 0.740
# Epoch 568: train accuracy = 0.710, test accuracy = 0.620
# Epoch 569: train accuracy = 0.560, test accuracy = 0.740
# Epoch 570: train accuracy = 0.710, test accuracy = 0.620
# Epoch 571: train accuracy = 0.560, test accuracy = 0.740
# Epoch 572: train accuracy = 0.710, test accuracy = 0.620
# Epoch 573: train accuracy = 0.560, test accuracy = 0.740
# Epoch 574: train accuracy = 0.710, test accuracy = 0.620
# Epoch 575: train accuracy = 0.560, test accuracy = 0.740
# Epoch 576: train accuracy = 0.710, test accuracy = 0.620
# Epoch 577: train accuracy = 0.560, test accuracy = 0.740
# Epoch 578: train accuracy = 0.710, test accuracy = 0.620
# Epoch 579: train accuracy = 0.560, test accuracy = 0.740
# Epoch 580: train accuracy = 0.710, test accuracy = 0.620
# Epoch 581: train accuracy = 0.560, test accuracy = 0.740
# Epoch 582: train accuracy = 0.710, test accuracy = 0.620
# Epoch 583: train accuracy = 0.560, test accuracy = 0.740
# Epoch 584: train accuracy = 0.710, test accuracy = 0.620
# Epoch 585: train accuracy = 0.560, test accuracy = 0.740
# Epoch 586: train accuracy = 0.710, test accuracy = 0.620
# Epoch 587: train accuracy = 0.560, test accuracy = 0.740
# Epoch 588: train accuracy = 0.710, test accuracy = 0.620
# Epoch 589: train accuracy = 0.560, test accuracy = 0.740
# Epoch 590: train accuracy = 0.710, test accuracy = 0.620
# Epoch 591: train accuracy = 0.560, test accuracy = 0.740
# Epoch 592: train accuracy = 0.710, test accuracy = 0.620
# Epoch 593: train accuracy = 0.560, test accuracy = 0.740
# Epoch 594: train accuracy = 0.710, test accuracy = 0.620
# Epoch 595: train accuracy = 0.560, test accuracy = 0.740
# Epoch 596: train accuracy = 0.710, test accuracy = 0.620
# Epoch 597: train accuracy = 0.560, test accuracy = 0.740
# Epoch 598: train accuracy = 0.710, test accuracy = 0.620
# Epoch 599: train accuracy = 0.560, test accuracy = 0.740
# Epoch 600: train accuracy = 0.710, test accuracy = 0.620
# Epoch 601: train accuracy = 0.560, test accuracy = 0.740
# Epoch 602: train accuracy = 0.710, test accuracy = 0.620
# Epoch 603: train accuracy = 0.560, test accuracy = 0.740
# Epoch 604: train accuracy = 0.710, test accuracy = 0.620
# Epoch 605: train accuracy = 0.560, test accuracy = 0.740
# Epoch 606: train accuracy = 0.710, test accuracy = 0.620
# Epoch 607: train accuracy = 0.560, test accuracy = 0.740
# Epoch 608: train accuracy = 0.710, test accuracy = 0.620
# Epoch 609: train accuracy = 0.560, test accuracy = 0.740
# Epoch 610: train accuracy = 0.710, test accuracy = 0.620
# Epoch 611: train accuracy = 0.560, test accuracy = 0.740
# Epoch 612: train accuracy = 0.710, test accuracy = 0.620
# Epoch 613: train accuracy = 0.560, test accuracy = 0.750
# Epoch 614: train accuracy = 0.710, test accuracy = 0.620
# Epoch 615: train accuracy = 0.560, test accuracy = 0.750
# Epoch 616: train accuracy = 0.710, test accuracy = 0.620
# Epoch 617: train accuracy = 0.560, test accuracy = 0.760
# Epoch 618: train accuracy = 0.700, test accuracy = 0.620
# Epoch 619: train accuracy = 0.560, test accuracy = 0.760
# Epoch 620: train accuracy = 0.700, test accuracy = 0.620
# Epoch 621: train accuracy = 0.560, test accuracy = 0.760
# Epoch 622: train accuracy = 0.690, test accuracy = 0.620
# Epoch 623: train accuracy = 0.560, test accuracy = 0.760
# Epoch 624: train accuracy = 0.690, test accuracy = 0.620
# Epoch 625: train accuracy = 0.550, test accuracy = 0.760
# Epoch 626: train accuracy = 0.690, test accuracy = 0.620
# Epoch 627: train accuracy = 0.550, test accuracy = 0.760
# Epoch 628: train accuracy = 0.690, test accuracy = 0.620
# Epoch 629: train accuracy = 0.550, test accuracy = 0.760
# Epoch 630: train accuracy = 0.690, test accuracy = 0.620
# Epoch 631: train accuracy = 0.550, test accuracy = 0.760
# Epoch 632: train accuracy = 0.690, test accuracy = 0.620
# Epoch 633: train accuracy = 0.560, test accuracy = 0.760
# Epoch 634: train accuracy = 0.690, test accuracy = 0.620
# Epoch 635: train accuracy = 0.560, test accuracy = 0.760
# Epoch 636: train accuracy = 0.690, test accuracy = 0.620
# Epoch 637: train accuracy = 0.560, test accuracy = 0.760
# Epoch 638: train accuracy = 0.690, test accuracy = 0.620
# Epoch 639: train accuracy = 0.570, test accuracy = 0.760
# Epoch 640: train accuracy = 0.690, test accuracy = 0.620
# Epoch 641: train accuracy = 0.570, test accuracy = 0.760
# Epoch 642: train accuracy = 0.690, test accuracy = 0.620
# Epoch 643: train accuracy = 0.570, test accuracy = 0.760
# Epoch 644: train accuracy = 0.690, test accuracy = 0.620
# Epoch 645: train accuracy = 0.570, test accuracy = 0.760
# Epoch 646: train accuracy = 0.690, test accuracy = 0.620
# Epoch 647: train accuracy = 0.570, test accuracy = 0.760
# Epoch 648: train accuracy = 0.690, test accuracy = 0.620
# Epoch 649: train accuracy = 0.570, test accuracy = 0.760
# Epoch 650: train accuracy = 0.690, test accuracy = 0.620
# Epoch 651: train accuracy = 0.570, test accuracy = 0.760
# Epoch 652: train accuracy = 0.690, test accuracy = 0.620
# Epoch 653: train accuracy = 0.570, test accuracy = 0.760
# Epoch 654: train accuracy = 0.690, test accuracy = 0.620
# Epoch 655: train accuracy = 0.570, test accuracy = 0.760
# Epoch 656: train accuracy = 0.690, test accuracy = 0.620
# Epoch 657: train accuracy = 0.570, test accuracy = 0.760
# Epoch 658: train accuracy = 0.690, test accuracy = 0.620
# Epoch 659: train accuracy = 0.570, test accuracy = 0.760
# Epoch 660: train accuracy = 0.690, test accuracy = 0.620
# Epoch 661: train accuracy = 0.570, test accuracy = 0.760
# Epoch 662: train accuracy = 0.690, test accuracy = 0.620
# Epoch 663: train accuracy = 0.570, test accuracy = 0.760
# Epoch 664: train accuracy = 0.690, test accuracy = 0.620
# Epoch 665: train accuracy = 0.570, test accuracy = 0.760
# Epoch 666: train accuracy = 0.690, test accuracy = 0.620
# Epoch 667: train accuracy = 0.570, test accuracy = 0.760
# Epoch 668: train accuracy = 0.690, test accuracy = 0.620
# Epoch 669: train accuracy = 0.570, test accuracy = 0.760
# Epoch 670: train accuracy = 0.690, test accuracy = 0.620
# Epoch 671: train accuracy = 0.570, test accuracy = 0.760
# Epoch 672: train accuracy = 0.690, test accuracy = 0.620
# Epoch 673: train accuracy = 0.570, test accuracy = 0.760
# Epoch 674: train accuracy = 0.690, test accuracy = 0.620
# Epoch 675: train accuracy = 0.570, test accuracy = 0.760
# Epoch 676: train accuracy = 0.690, test accuracy = 0.620
# Epoch 677: train accuracy = 0.570, test accuracy = 0.760
# Epoch 678: train accuracy = 0.690, test accuracy = 0.620
# Epoch 679: train accuracy = 0.570, test accuracy = 0.760
# Epoch 680: train accuracy = 0.690, test accuracy = 0.620
# Epoch 681: train accuracy = 0.570, test accuracy = 0.760
# Epoch 682: train accuracy = 0.690, test accuracy = 0.620
# Epoch 683: train accuracy = 0.570, test accuracy = 0.760
# Epoch 684: train accuracy = 0.690, test accuracy = 0.620
# Epoch 685: train accuracy = 0.570, test accuracy = 0.760
# Epoch 686: train accuracy = 0.690, test accuracy = 0.620
# Epoch 687: train accuracy = 0.570, test accuracy = 0.760
# Epoch 688: train accuracy = 0.690, test accuracy = 0.620
# Epoch 689: train accuracy = 0.570, test accuracy = 0.760
# Epoch 690: train accuracy = 0.690, test accuracy = 0.620
# Epoch 691: train accuracy = 0.570, test accuracy = 0.760
# Epoch 692: train accuracy = 0.690, test accuracy = 0.620
# Epoch 693: train accuracy = 0.570, test accuracy = 0.760
# Epoch 694: train accuracy = 0.690, test accuracy = 0.620
# Epoch 695: train accuracy = 0.570, test accuracy = 0.760
# Epoch 696: train accuracy = 0.690, test accuracy = 0.620
# Epoch 697: train accuracy = 0.570, test accuracy = 0.760
# Epoch 698: train accuracy = 0.690, test accuracy = 0.620
# Epoch 699: train accuracy = 0.570, test accuracy = 0.760
# Epoch 700: train accuracy = 0.690, test accuracy = 0.620
# Epoch 701: train accuracy = 0.570, test accuracy = 0.760
# Epoch 702: train accuracy = 0.690, test accuracy = 0.620
# Epoch 703: train accuracy = 0.570, test accuracy = 0.760
# Epoch 704: train accuracy = 0.690, test accuracy = 0.620
# Epoch 705: train accuracy = 0.570, test accuracy = 0.760
# Epoch 706: train accuracy = 0.690, test accuracy = 0.620
# Epoch 707: train accuracy = 0.570, test accuracy = 0.760
# Epoch 708: train accuracy = 0.690, test accuracy = 0.620
# Epoch 709: train accuracy = 0.570, test accuracy = 0.760
# Epoch 710: train accuracy = 0.690, test accuracy = 0.620
# Epoch 711: train accuracy = 0.570, test accuracy = 0.760
# Epoch 712: train accuracy = 0.690, test accuracy = 0.620
# Epoch 713: train accuracy = 0.570, test accuracy = 0.760
# Epoch 714: train accuracy = 0.690, test accuracy = 0.620
# Epoch 715: train accuracy = 0.570, test accuracy = 0.760
# Epoch 716: train accuracy = 0.690, test accuracy = 0.620
# Epoch 717: train accuracy = 0.570, test accuracy = 0.760
# Epoch 718: train accuracy = 0.690, test accuracy = 0.620
# Epoch 719: train accuracy = 0.570, test accuracy = 0.760
# Epoch 720: train accuracy = 0.690, test accuracy = 0.620
# Epoch 721: train accuracy = 0.570, test accuracy = 0.760
# Epoch 722: train accuracy = 0.690, test accuracy = 0.620
# Epoch 723: train accuracy = 0.570, test accuracy = 0.760
# Epoch 724: train accuracy = 0.690, test accuracy = 0.620
# Epoch 725: train accuracy = 0.570, test accuracy = 0.760
# Epoch 726: train accuracy = 0.690, test accuracy = 0.620
# Epoch 727: train accuracy = 0.570, test accuracy = 0.760
# Epoch 728: train accuracy = 0.690, test accuracy = 0.620
# Epoch 729: train accuracy = 0.570, test accuracy = 0.760
# Epoch 730: train accuracy = 0.690, test accuracy = 0.620
# Epoch 731: train accuracy = 0.570, test accuracy = 0.760
# Epoch 732: train accuracy = 0.690, test accuracy = 0.620
# Epoch 733: train accuracy = 0.570, test accuracy = 0.760
# Epoch 734: train accuracy = 0.690, test accuracy = 0.620
# Epoch 735: train accuracy = 0.570, test accuracy = 0.760
# Epoch 736: train accuracy = 0.690, test accuracy = 0.620
# Epoch 737: train accuracy = 0.570, test accuracy = 0.760
# Epoch 738: train accuracy = 0.690, test accuracy = 0.620
# Epoch 739: train accuracy = 0.570, test accuracy = 0.760
# Epoch 740: train accuracy = 0.690, test accuracy = 0.620
# Epoch 741: train accuracy = 0.570, test accuracy = 0.760
# Epoch 742: train accuracy = 0.690, test accuracy = 0.620
# Epoch 743: train accuracy = 0.570, test accuracy = 0.760
# Epoch 744: train accuracy = 0.690, test accuracy = 0.620
# Epoch 745: train accuracy = 0.570, test accuracy = 0.760
# Epoch 746: train accuracy = 0.690, test accuracy = 0.620
# Epoch 747: train accuracy = 0.570, test accuracy = 0.760
# Epoch 748: train accuracy = 0.690, test accuracy = 0.620
# Epoch 749: train accuracy = 0.570, test accuracy = 0.760
# Epoch 750: train accuracy = 0.690, test accuracy = 0.620
# Epoch 751: train accuracy = 0.570, test accuracy = 0.760
# Epoch 752: train accuracy = 0.690, test accuracy = 0.620
# Epoch 753: train accuracy = 0.570, test accuracy = 0.760
# Epoch 754: train accuracy = 0.690, test accuracy = 0.620
# Epoch 755: train accuracy = 0.570, test accuracy = 0.760
# Epoch 756: train accuracy = 0.690, test accuracy = 0.620
# Epoch 757: train accuracy = 0.570, test accuracy = 0.760
# Epoch 758: train accuracy = 0.690, test accuracy = 0.620
# Epoch 759: train accuracy = 0.570, test accuracy = 0.760
# Epoch 760: train accuracy = 0.690, test accuracy = 0.620
# Epoch 761: train accuracy = 0.570, test accuracy = 0.760
# Epoch 762: train accuracy = 0.690, test accuracy = 0.620
# Epoch 763: train accuracy = 0.570, test accuracy = 0.760
# Epoch 764: train accuracy = 0.690, test accuracy = 0.620
# Epoch 765: train accuracy = 0.570, test accuracy = 0.760
# Epoch 766: train accuracy = 0.690, test accuracy = 0.620
# Epoch 767: train accuracy = 0.570, test accuracy = 0.760
# Epoch 768: train accuracy = 0.690, test accuracy = 0.620
# Epoch 769: train accuracy = 0.570, test accuracy = 0.760
# Epoch 770: train accuracy = 0.690, test accuracy = 0.620
# Epoch 771: train accuracy = 0.570, test accuracy = 0.760
# Epoch 772: train accuracy = 0.690, test accuracy = 0.620
# Epoch 773: train accuracy = 0.570, test accuracy = 0.760
# Epoch 774: train accuracy = 0.690, test accuracy = 0.620
# Epoch 775: train accuracy = 0.570, test accuracy = 0.760
# Epoch 776: train accuracy = 0.690, test accuracy = 0.620
# Epoch 777: train accuracy = 0.570, test accuracy = 0.760
# Epoch 778: train accuracy = 0.690, test accuracy = 0.620
# Epoch 779: train accuracy = 0.570, test accuracy = 0.760
# Epoch 780: train accuracy = 0.690, test accuracy = 0.620
# Epoch 781: train accuracy = 0.570, test accuracy = 0.760
# Epoch 782: train accuracy = 0.690, test accuracy = 0.620
# Epoch 783: train accuracy = 0.570, test accuracy = 0.760
# Epoch 784: train accuracy = 0.690, test accuracy = 0.620
# Epoch 785: train accuracy = 0.570, test accuracy = 0.760
# Epoch 786: train accuracy = 0.690, test accuracy = 0.620
# Epoch 787: train accuracy = 0.570, test accuracy = 0.760
# Epoch 788: train accuracy = 0.690, test accuracy = 0.620
# Epoch 789: train accuracy = 0.570, test accuracy = 0.760
# Epoch 790: train accuracy = 0.690, test accuracy = 0.620
# Epoch 791: train accuracy = 0.570, test accuracy = 0.760
# Epoch 792: train accuracy = 0.690, test accuracy = 0.620
# Epoch 793: train accuracy = 0.570, test accuracy = 0.760
# Epoch 794: train accuracy = 0.690, test accuracy = 0.620
# Epoch 795: train accuracy = 0.570, test accuracy = 0.760
# Epoch 796: train accuracy = 0.690, test accuracy = 0.620
# Epoch 797: train accuracy = 0.570, test accuracy = 0.760
# Epoch 798: train accuracy = 0.690, test accuracy = 0.620
# Epoch 799: train accuracy = 0.570, test accuracy = 0.760
# Epoch 800: train accuracy = 0.690, test accuracy = 0.620
# Epoch 801: train accuracy = 0.570, test accuracy = 0.760
# Epoch 802: train accuracy = 0.690, test accuracy = 0.620
# Epoch 803: train accuracy = 0.570, test accuracy = 0.760
# Epoch 804: train accuracy = 0.690, test accuracy = 0.620
# Epoch 805: train accuracy = 0.570, test accuracy = 0.760
# Epoch 806: train accuracy = 0.690, test accuracy = 0.620
# Epoch 807: train accuracy = 0.570, test accuracy = 0.760
# Epoch 808: train accuracy = 0.690, test accuracy = 0.620
# Epoch 809: train accuracy = 0.570, test accuracy = 0.760
# Epoch 810: train accuracy = 0.690, test accuracy = 0.620
# Epoch 811: train accuracy = 0.570, test accuracy = 0.760
# Epoch 812: train accuracy = 0.690, test accuracy = 0.620
# Epoch 813: train accuracy = 0.570, test accuracy = 0.760
# Epoch 814: train accuracy = 0.690, test accuracy = 0.620
# Epoch 815: train accuracy = 0.570, test accuracy = 0.760
# Epoch 816: train accuracy = 0.690, test accuracy = 0.620
# Epoch 817: train accuracy = 0.570, test accuracy = 0.760
# Epoch 818: train accuracy = 0.690, test accuracy = 0.620
# Epoch 819: train accuracy = 0.570, test accuracy = 0.760
# Epoch 820: train accuracy = 0.690, test accuracy = 0.620
# Epoch 821: train accuracy = 0.570, test accuracy = 0.760
# Epoch 822: train accuracy = 0.690, test accuracy = 0.620
# Epoch 823: train accuracy = 0.570, test accuracy = 0.760
# Epoch 824: train accuracy = 0.690, test accuracy = 0.620
# Epoch 825: train accuracy = 0.570, test accuracy = 0.760
# Epoch 826: train accuracy = 0.690, test accuracy = 0.620
# Epoch 827: train accuracy = 0.570, test accuracy = 0.760
# Epoch 828: train accuracy = 0.690, test accuracy = 0.620
# Epoch 829: train accuracy = 0.570, test accuracy = 0.760
# Epoch 830: train accuracy = 0.690, test accuracy = 0.620
# Epoch 831: train accuracy = 0.570, test accuracy = 0.760
# Epoch 832: train accuracy = 0.690, test accuracy = 0.620
# Epoch 833: train accuracy = 0.570, test accuracy = 0.760
# Epoch 834: train accuracy = 0.690, test accuracy = 0.620
# Epoch 835: train accuracy = 0.570, test accuracy = 0.760
# Epoch 836: train accuracy = 0.690, test accuracy = 0.620
# Epoch 837: train accuracy = 0.570, test accuracy = 0.760
# Epoch 838: train accuracy = 0.690, test accuracy = 0.620
# Epoch 839: train accuracy = 0.570, test accuracy = 0.760
# Epoch 840: train accuracy = 0.690, test accuracy = 0.620
# Epoch 841: train accuracy = 0.570, test accuracy = 0.760
# Epoch 842: train accuracy = 0.690, test accuracy = 0.620
# Epoch 843: train accuracy = 0.570, test accuracy = 0.760
# Epoch 844: train accuracy = 0.690, test accuracy = 0.620
# Epoch 845: train accuracy = 0.570, test accuracy = 0.760
# Epoch 846: train accuracy = 0.690, test accuracy = 0.620
# Epoch 847: train accuracy = 0.570, test accuracy = 0.760
# Epoch 848: train accuracy = 0.690, test accuracy = 0.620
# Epoch 849: train accuracy = 0.570, test accuracy = 0.760
# Epoch 850: train accuracy = 0.690, test accuracy = 0.620
# Epoch 851: train accuracy = 0.570, test accuracy = 0.760
# Epoch 852: train accuracy = 0.690, test accuracy = 0.620
# Epoch 853: train accuracy = 0.570, test accuracy = 0.760
# Epoch 854: train accuracy = 0.690, test accuracy = 0.620
# Epoch 855: train accuracy = 0.570, test accuracy = 0.760
# Epoch 856: train accuracy = 0.690, test accuracy = 0.620
# Epoch 857: train accuracy = 0.570, test accuracy = 0.760
# Epoch 858: train accuracy = 0.690, test accuracy = 0.620
# Epoch 859: train accuracy = 0.570, test accuracy = 0.760
# Epoch 860: train accuracy = 0.690, test accuracy = 0.620
# Epoch 861: train accuracy = 0.570, test accuracy = 0.760
# Epoch 862: train accuracy = 0.690, test accuracy = 0.620
# Epoch 863: train accuracy = 0.570, test accuracy = 0.760
# Epoch 864: train accuracy = 0.690, test accuracy = 0.620
# Epoch 865: train accuracy = 0.570, test accuracy = 0.760
# Epoch 866: train accuracy = 0.690, test accuracy = 0.620
# Epoch 867: train accuracy = 0.570, test accuracy = 0.760
# Epoch 868: train accuracy = 0.690, test accuracy = 0.620
# Epoch 869: train accuracy = 0.570, test accuracy = 0.760
# Epoch 870: train accuracy = 0.690, test accuracy = 0.620
# Epoch 871: train accuracy = 0.570, test accuracy = 0.760
# Epoch 872: train accuracy = 0.690, test accuracy = 0.620
# Epoch 873: train accuracy = 0.570, test accuracy = 0.760
# Epoch 874: train accuracy = 0.690, test accuracy = 0.620
# Epoch 875: train accuracy = 0.570, test accuracy = 0.760
# Epoch 876: train accuracy = 0.690, test accuracy = 0.620
# Epoch 877: train accuracy = 0.570, test accuracy = 0.760
# Epoch 878: train accuracy = 0.690, test accuracy = 0.620
# Epoch 879: train accuracy = 0.570, test accuracy = 0.760
# Epoch 880: train accuracy = 0.690, test accuracy = 0.620
# Epoch 881: train accuracy = 0.570, test accuracy = 0.760
# Epoch 882: train accuracy = 0.690, test accuracy = 0.620
# Epoch 883: train accuracy = 0.570, test accuracy = 0.760
# Epoch 884: train accuracy = 0.690, test accuracy = 0.620
# Epoch 885: train accuracy = 0.570, test accuracy = 0.760
# Epoch 886: train accuracy = 0.690, test accuracy = 0.620
# Epoch 887: train accuracy = 0.570, test accuracy = 0.760
# Epoch 888: train accuracy = 0.690, test accuracy = 0.620
# Epoch 889: train accuracy = 0.570, test accuracy = 0.760
# Epoch 890: train accuracy = 0.690, test accuracy = 0.620
# Epoch 891: train accuracy = 0.570, test accuracy = 0.760
# Epoch 892: train accuracy = 0.690, test accuracy = 0.620
# Epoch 893: train accuracy = 0.570, test accuracy = 0.760
# Epoch 894: train accuracy = 0.690, test accuracy = 0.620
# Epoch 895: train accuracy = 0.570, test accuracy = 0.760
# Epoch 896: train accuracy = 0.690, test accuracy = 0.620
# Epoch 897: train accuracy = 0.570, test accuracy = 0.760
# Epoch 898: train accuracy = 0.690, test accuracy = 0.620
# Epoch 899: train accuracy = 0.570, test accuracy = 0.760
# Epoch 900: train accuracy = 0.690, test accuracy = 0.620
# Epoch 901: train accuracy = 0.570, test accuracy = 0.760
# Epoch 902: train accuracy = 0.690, test accuracy = 0.620
# Epoch 903: train accuracy = 0.570, test accuracy = 0.760
# Epoch 904: train accuracy = 0.690, test accuracy = 0.620
# Epoch 905: train accuracy = 0.570, test accuracy = 0.760
# Epoch 906: train accuracy = 0.690, test accuracy = 0.620
# Epoch 907: train accuracy = 0.570, test accuracy = 0.760
# Epoch 908: train accuracy = 0.690, test accuracy = 0.620
# Epoch 909: train accuracy = 0.570, test accuracy = 0.760
# Epoch 910: train accuracy = 0.690, test accuracy = 0.620
# Epoch 911: train accuracy = 0.570, test accuracy = 0.760
# Epoch 912: train accuracy = 0.690, test accuracy = 0.620
# Epoch 913: train accuracy = 0.570, test accuracy = 0.760
# Epoch 914: train accuracy = 0.690, test accuracy = 0.620
# Epoch 915: train accuracy = 0.570, test accuracy = 0.760
# Epoch 916: train accuracy = 0.690, test accuracy = 0.620
# Epoch 917: train accuracy = 0.570, test accuracy = 0.760
# Epoch 918: train accuracy = 0.690, test accuracy = 0.620
# Epoch 919: train accuracy = 0.570, test accuracy = 0.760
# Epoch 920: train accuracy = 0.690, test accuracy = 0.620
# Epoch 921: train accuracy = 0.570, test accuracy = 0.760
# Epoch 922: train accuracy = 0.690, test accuracy = 0.620
# Epoch 923: train accuracy = 0.570, test accuracy = 0.760
# Epoch 924: train accuracy = 0.690, test accuracy = 0.620
# Epoch 925: train accuracy = 0.570, test accuracy = 0.760
# Epoch 926: train accuracy = 0.690, test accuracy = 0.620
# Epoch 927: train accuracy = 0.570, test accuracy = 0.760
# Epoch 928: train accuracy = 0.690, test accuracy = 0.620
# Epoch 929: train accuracy = 0.570, test accuracy = 0.760
# Epoch 930: train accuracy = 0.690, test accuracy = 0.620
# Epoch 931: train accuracy = 0.570, test accuracy = 0.760
# Epoch 932: train accuracy = 0.690, test accuracy = 0.620
# Epoch 933: train accuracy = 0.570, test accuracy = 0.760
# Epoch 934: train accuracy = 0.690, test accuracy = 0.620
# Epoch 935: train accuracy = 0.570, test accuracy = 0.760
# Epoch 936: train accuracy = 0.690, test accuracy = 0.620
# Epoch 937: train accuracy = 0.570, test accuracy = 0.760
# Epoch 938: train accuracy = 0.690, test accuracy = 0.620
# Epoch 939: train accuracy = 0.570, test accuracy = 0.760
# Epoch 940: train accuracy = 0.690, test accuracy = 0.620
# Epoch 941: train accuracy = 0.570, test accuracy = 0.760
# Epoch 942: train accuracy = 0.690, test accuracy = 0.620
# Epoch 943: train accuracy = 0.570, test accuracy = 0.760
# Epoch 944: train accuracy = 0.690, test accuracy = 0.620
# Epoch 945: train accuracy = 0.570, test accuracy = 0.760
# Epoch 946: train accuracy = 0.690, test accuracy = 0.620
# Epoch 947: train accuracy = 0.570, test accuracy = 0.760
# Epoch 948: train accuracy = 0.690, test accuracy = 0.620
# Epoch 949: train accuracy = 0.570, test accuracy = 0.760
# Epoch 950: train accuracy = 0.690, test accuracy = 0.620
# Epoch 951: train accuracy = 0.570, test accuracy = 0.760
# Epoch 952: train accuracy = 0.690, test accuracy = 0.620
# Epoch 953: train accuracy = 0.570, test accuracy = 0.760
# Epoch 954: train accuracy = 0.690, test accuracy = 0.620
# Epoch 955: train accuracy = 0.570, test accuracy = 0.760
# Epoch 956: train accuracy = 0.690, test accuracy = 0.620
# Epoch 957: train accuracy = 0.570, test accuracy = 0.760
# Epoch 958: train accuracy = 0.690, test accuracy = 0.620
# Epoch 959: train accuracy = 0.570, test accuracy = 0.760
# Epoch 960: train accuracy = 0.690, test accuracy = 0.620
# Epoch 961: train accuracy = 0.570, test accuracy = 0.760
# Epoch 962: train accuracy = 0.690, test accuracy = 0.620
# Epoch 963: train accuracy = 0.570, test accuracy = 0.760
# Epoch 964: train accuracy = 0.690, test accuracy = 0.620
# Epoch 965: train accuracy = 0.570, test accuracy = 0.760
# Epoch 966: train accuracy = 0.690, test accuracy = 0.620
# Epoch 967: train accuracy = 0.570, test accuracy = 0.760
# Epoch 968: train accuracy = 0.690, test accuracy = 0.620
# Epoch 969: train accuracy = 0.570, test accuracy = 0.760
# Epoch 970: train accuracy = 0.690, test accuracy = 0.620
# Epoch 971: train accuracy = 0.570, test accuracy = 0.760
# Epoch 972: train accuracy = 0.690, test accuracy = 0.620
# Epoch 973: train accuracy = 0.570, test accuracy = 0.760
# Epoch 974: train accuracy = 0.690, test accuracy = 0.620
# Epoch 975: train accuracy = 0.570, test accuracy = 0.760
# Epoch 976: train accuracy = 0.690, test accuracy = 0.620
# Epoch 977: train accuracy = 0.570, test accuracy = 0.760
# Epoch 978: train accuracy = 0.690, test accuracy = 0.620
# Epoch 979: train accuracy = 0.570, test accuracy = 0.760
# Epoch 980: train accuracy = 0.690, test accuracy = 0.620
# Epoch 981: train accuracy = 0.570, test accuracy = 0.760
# Epoch 982: train accuracy = 0.690, test accuracy = 0.620
# Epoch 983: train accuracy = 0.570, test accuracy = 0.760
# Epoch 984: train accuracy = 0.690, test accuracy = 0.620
# Epoch 985: train accuracy = 0.570, test accuracy = 0.760
# Epoch 986: train accuracy = 0.690, test accuracy = 0.620
# Epoch 987: train accuracy = 0.570, test accuracy = 0.760
# Epoch 988: train accuracy = 0.690, test accuracy = 0.620
# Epoch 989: train accuracy = 0.570, test accuracy = 0.760
# Epoch 990: train accuracy = 0.690, test accuracy = 0.620
# Epoch 991: train accuracy = 0.570, test accuracy = 0.760
# Epoch 992: train accuracy = 0.690, test accuracy = 0.620
# Epoch 993: train accuracy = 0.570, test accuracy = 0.760
# Epoch 994: train accuracy = 0.690, test accuracy = 0.620
# Epoch 995: train accuracy = 0.570, test accuracy = 0.760
# Epoch 996: train accuracy = 0.690, test accuracy = 0.620
# Epoch 997: train accuracy = 0.570, test accuracy = 0.760
# Epoch 998: train accuracy = 0.690, test accuracy = 0.620
# Epoch 999: train accuracy = 0.570, test accuracy = 0.760
# Hyperplane 0: w = [-0.26857464  1.46090885], b = -0.7422579880724662
# Hyperplane 1: w = [-0.37059851  0.43888739], b = 0.5110669271493554
# Hyperplane 2: w = [-0.26840178 -0.09327991], b = 0.18187316492833797
# Hyperplane 3: w = [ 0.0010686  -0.31473313], b = 0.05670721177243013
# Hyperplane 4: w = [-0.18944107 -0.12852761], b = 0.1020089766982326
# Hyperplane 5: w = [-0.17946778  0.25138843], b = 0.06409001284636055
# Hyperplane 6: w = [-0.00771898 -0.32184241], b = 0.02448637543528049
# Hyperplane 7: w = [-0.19829288 -0.21474272], b = 0.10440471137936537
# Hyperplane 8: w = [0.68014957 1.61642264], b = -0.5088369261365564
# Hyperplane 9: w = [-0.21031908 -0.14040968], b = 0.03371391140522248

# %%
import matplotlib.pyplot as plt

# plot the weight vectors as arrows
for i in range(hidden_size):
    w = weights1[:, i]
    plt.arrow(a, b, w[0]*0.1, w[1]*0.1, head_width=0.05, head_length=0.1, fc='k', ec='k')
    plt.text(a + w[0]*0.1, b + w[1]*0.1, f'w{i}', fontsize=10, ha='center', va='center')

# plot the hyperplanes as lines perpendicular to the weight vectors
for i in range(hidden_size):
    w = weights1[:, i]
    b = -w.dot(np.array([a, b]))
    x = np.linspace(0, 1, 100)
    y = (-w[0] * x - b) / w[1]
    plt.plot(x, y, label=f"Hyperplane {i}")

# plot the training data points
for i in range(num_samples):
    x, y = train_inputs[i]
    if train_outputs[i] == 1:
        plt.plot(x, y, 'bo')
    else:
        plt.plot(x, y, 'ro')

# plot the testing data points
for i in range(num_samples):
    x, y = test_inputs[i]
    if test_outputs[i] == 1:
        plt.plot(x, y, 'bx')
    else:
        plt.plot(x, y, 'rx')

plt.legend()
plt.show()
